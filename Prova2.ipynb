# %%
# dado o codigo a seguir que contem uma implementação incompleta e com falhas de algoritimo de selection sort.
# implementação selection sort c/ falhas 

def selection_sort(arr):
    for i in range(len(arr)-1):
        min_idx = i = 1 
        for j in range(i, len(arr)):
            if arr[J] < arr[i]:
                min_idx = j 
        arr[min_idx] = arr[1]
        arr[i] = arr[min_idx]
    return arr

# %%
def selection_sort(arr):
    n = len(arr)                                # Obtém o tamanho da lista (n).
    
    # percorre a lista e o menor elemento:
    for i in range(n - 1):                       # Loop principal, vai do índice 0 até o penúltimo.
        
        #teste
        min_idx = i                              # Assume o menor elemento está na posição.
        
        # Procura o menor elemento.
        for j in range(i + 1, n):                # CORREÇÃO: Inicia a busca (j) no índice seguinte a 'i', e vai até o final.
            
            # teste tamanho
            if arr[j] < arr[min_idx]:            # Se o elemento em 'j' for menor que o atual
                min_idx = j                      # atualiza 'min_idx' para 'j', que é o índice do menor valor encontrado.
        
        # Troca : Realizada após o loop interno encontrar o menor.
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
                                                 # Troca os valores
    return arr                                   # Retorna a lista 
    
# maior elemento
def find_max(Lista_ordenada):
    if Lista_ordenada:
        return Lista_ordenada[-1]                # Retorna o último elemento da lista, que é o maior após a ordenação.
    return None

# Execução
lista_original = random.sample(range(1, 51), 7) 
print(f"Lista Original: {lista_original}")
lista_ordenada = selection_sort(lista_original)
print(f"Lista Ordenada: {lista_ordenada}")
maior = find_max(lista_ordenada)
print(f"Maior Elemento: {maior}")
# Out:
# Lista Original: [31, 13, 33, 11, 16, 10, 41]
# Lista Ordenada: [10, 11, 13, 16, 31, 33, 41]
# Maior Elemento: 41
